# %%
#Library

from tensorflow.keras.preprocessing.image import load_img

# %%
#reading/loading image
img = load_img("Dataset/a.jpg")#PIL şeklinde resim okur

print("Type:",type(img))
print("Format:",img.format)
print("Size:",img.size)
print("Mode:",img.mode,end = "\n\n")

print("All properties:",img)
# Out:
# Type: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Format: JPEG
# Size: (333, 151)
# Mode: RGB
#
# All properties: <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=333x151 at 0x22C0BA0DD20>

# %%
#displaying image
import matplotlib.pyplot as plt

img = load_img("Dataset/a.jpg")
img1 = load_img("Dataset/b.jpg")

plt.imshow(img)
plt.show()
plt.imshow(img1)
plt.show()

# %%
#PIL --> numpy array
from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img

img = load_img("Dataset/a.jpg")
print("Type first:",type(img))

img = img_to_array(img)
print("Type second:",type(img))

img = array_to_img(img)
print("Type last:",type(img))
# Out:
# Type first: <class 'PIL.JpegImagePlugin.JpegImageFile'>
# Type second: <class 'numpy.ndarray'>
# Type last: <class 'PIL.Image.Image'>
